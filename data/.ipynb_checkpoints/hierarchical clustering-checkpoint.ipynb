# %%
import numpy as np
from preprocess import *
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from scipy.cluster.hierarchy import dendrogram, linkage


stop_list = nltk.corpus.stopwords.words('english')
lemmatizer = WordNetLemmatizer()

folder_path = 'preprocessed2'  # Replace with path to your folder
sentences = []

# Iterate over all files in the folder
for filename in os.listdir(folder_path):
    if filename.endswith('.txt'):
        # Read the text file and store the text in the sentences list
        with open(os.path.join(folder_path, filename), 'r') as f:
            document = f.readlines()
            for sentence in document:
                sentences.append(sentence)

# Create a bag-of-words matrix
vectorizer = CountVectorizer()
word_matrix = vectorizer.fit_transform(sentences).toarray()

# Perform agglomerative clustering
Z = linkage(word_matrix, 'ward')

# Plot the dendrogram
plt.figure(figsize=(20, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('sentences')
plt.ylabel('Distance')
dendrogram(Z, leaf_rotation=90., leaf_font_size=5., labels=sentences)
plt.show()
# Out:
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 35251 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20096 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 26716 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 35090 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 36023 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 28288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32080 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24358 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 34030 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12480 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 31292 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32929 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 26435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 31080 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32463 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 26031 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 25289 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24052 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 33778 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24322 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21160 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32435 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 36798 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20811 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21843 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21046 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 22805 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119829 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 119858 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21177 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 29575 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 28168 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 25209 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 35413 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 50516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54840 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 54224 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 34395 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 25836 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24163 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21307 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 25285 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24403 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20685 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 35696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 38263 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 31859 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 33391 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 27497 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21448 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20104 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 30331 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 37682 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 39000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21496 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 22259 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 39208 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32887 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 21103 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 33073 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23652 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 24540 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 31572 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20170 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26085 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31309 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12415 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 19978 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12370 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27963 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12527 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12510 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12362 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12399 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25126 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12469 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12496 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12524 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35013 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31070 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23019 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30693 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12425 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12394 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12356 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27425 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20803 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12495 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12388 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20808 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 29983 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12471 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12467 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 37504 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 34892 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30772 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32187 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26666 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12500 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12459 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12525 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12460 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20027 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23142 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30701 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27468 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33382 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12371 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35251 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20809 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 22320 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20140 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 37117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20096 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23713 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26716 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12429 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12479 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12427 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20181 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35379 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32076 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36027 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21208 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23450 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31185 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30446 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35542 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25991 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12502 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12464 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12490 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24618 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35527 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24598 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35441 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30011 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20687 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25104 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24037 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26234 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33021 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32842 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 22825 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26426 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 22120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24335 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12461 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24466 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35352 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12472 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 29483 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20445 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35703 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12507 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20107 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 29640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 29746 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12390 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12355 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12387 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12513 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12392 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32331 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12364 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12426 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12383 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25237 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36039 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21475 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 45380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 46020 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 52404 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20449 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32676 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12511 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21021 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24515 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32773 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 39366 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12369 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20986 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12375 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12491 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12487 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 1729 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25100 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26519 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 19968 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33590 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26494 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23614 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 34121 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23569 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24180 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26178 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 38597 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24605 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36164 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 39118 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36187 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36947 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12372 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35090 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32654 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36023 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 29289 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 28288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36275 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24863 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26976 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23665 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31056 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36628 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12422 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12377 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12477 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12501 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32854 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26360 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12505 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 19990 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30028 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36578 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32701 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32080 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24358 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 40658 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 34030 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12354 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12391 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25935 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35789 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27719 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30005 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35745 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31639 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36895 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20661 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23433 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23460 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12419 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24425 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32418 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33616 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31726 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35910 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20248 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27431 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26479 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20139 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 39044 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27979 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 38283 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31038 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 29233 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20029 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 19997 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 28459 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35848 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31934 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30123 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33495 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 28781 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20849 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 36235 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21183 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27668 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27927 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21147 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21161 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21619 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24184 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24033 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21451 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27770 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26029 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35226 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32117 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 28310 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20633 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25313 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25955 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24076 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26395 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25551 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31036 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21610 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 40165 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24910 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12478 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 22580 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20365 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25165 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30142 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24739 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 25345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20142 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24291 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24651 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26377 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 21916 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 38556 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31119 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 31049 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 24310 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12400 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 30294 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12374 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import CountVectorizer
from scipy.cluster.hierarchy import dendrogram, linkage

# Load the text data
with open('dataframe_0_preprocessed.txt', 'r') as f:
    documents = f.readlines()

# Create a bag-of-words matrix
vectorizer = CountVectorizer()
word_matrix = vectorizer.fit_transform(documents).toarray()
print(documents)
# Perform agglomerative clustering
Z = linkage(word_matrix, 'ward')

# Plot the dendrogram
plt.figure(figsize=(10, 5))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Sample Index')
plt.ylabel('Distance')
dendrogram(Z, leaf_rotation=90., leaf_font_size=8., labels=documents)
plt.show()
# Out:
# ['I want to increase my Twitter followers. At least 10,000. #ChatGPT https://t.co/78BaGH28Vs\n', 'Overall, using AI to create art can expand the boundaries of creativity and allow artists to explore new directions in their work.  🧵4/4   @OpenAI #ChatGPT  👀\n', 'This prompt was created with #ChatGPT the new @OpenAI 🤯 chat model, the following #MartesDeDatos in @platzi we will talk about #ChatGPT and text-davinci-003 the new models for GPT3. 💚🚀 https://t.co/2cZVInL9bD\n', "Just played around with OpenAI's new #ChatGPT model and asked it to write a poem about embodied carbon in buildings. This is what I got...   Try out ChatGPT  https://t.co/vaov2Ttluo  #embodiedcarbon #poetry  https://t.co/DbgO6Qz2Zq\n", 'I asked #ChatGPT to write me a story about Sova and Jett falling in love...  https://t.co/yyZNrFRTQs\n', "OpenAI's new ChatGPT is very good at creative writing.  #openAI #chatGPT #poetry #Bitcoin  https://t.co/yxMfXVjxDB\n", 'This is a great improvement! Unlike text-davinci-003, #ChatGPT understands the context from previous user’s answers.\n', '#ChatGPT #OpenAI Wow!  https://t.co/aMUgPMtuoa\n', 'My mind is blown. I cannot believe how good ChatGPT from OpenAI is. I see this already replacing a lot of googling tasks I do, 100% right out of the box. I don’t even know what to say anymore. I must be doing something wrong. Someone please break it for me! #ChatGPT\n', 'Absolutely insane. I asked #chatGPT to generate a simple personal website.   It showed step by step on how to create it, then added HTML and CSS.   The output was used on @Replit. 🤯  https://t.co/yLigabNMAO\n', 'It is incredible how #chatgpt manages to propose an analysis of such magnitude and with a lot of sense @DotCSV https://t.co/AL4pMsgqN3\n', '#ChatGPT is pretty mind-blowing.  https://t.co/jXD5pGcTt9\n', 'OpenAIのChatGPT :)  https://t.co/oXakUrC9os @OpenAI #GPT3 #chatGPT #機械学習 #自然言語処理\n', '#ChatGPT from @OpenAI released today and is really something else. @sharplm, @EnglishOER , @anetv , @Charlesknight, @Inframethod  https://t.co/G7uE7h6nbY\n', '#ChatGPT from #OpenAI is here!\n', "The new #chatGPT from @openAI (thanks to @GuyP) is just astonishing: had a very interesting and illuminating conversation, although limited by its (structural) inability to access the web in real time. Much better than _anything_ ($&gt;=0) I've tried before.  Looking forward to GPT4\n", 'Write a poem about a little child longing to be an adult who is surfing social media on their phone. #ChatGPT. @pomeranian99  https://t.co/6eNALqreTf\n', 'In the not too distant future, a helpful assistant will be available that can answer your questions, do your tasks, give advice and eventually discover new knowledge for you! #ChatGPT\n', 'A cute little poem open about quarks from #ChatGPT, which was just released today. @pomeranian99  https://t.co/sYQmCWqz5T\n', 'I used @OpenAI new AI system #ChatGPT which is optimized for dialogue to generate a film treatment based The Great Gatsby by F. Scott Fitzgerald set in 2019 New York in Social Media era?   Here is the AI generated film treatment. 🧵\n', 'woops, just gave the AI an existential crisis #chatgpt #AI  https://t.co/qmIqzeTUby\n', 'Flipo with #ChatGPT https://t.co/Ii365D5Ehx\n', '#ChatGPT far too deep for me 🤯  https://t.co/iT7RI9mAQa\n', '@GuyP @OpenAI @readwise save thread @SaveToNotion #thread #openai #chatgpt\n', '#ChatGPT may not like children very much, but at least it knows how many others should die.  https://t.co/YAjhLNB6Rf\n', "@marmite I've just found a new member for your marketing team #ChatGPT  https://t.co/80ShBfBJXB\n", 'Superhero Academies, Apartments, Research and Development Facilities, Museums and Memorials #ChatGPT #StableDiffusion #AIArt 3/3  https://t.co/EAw1inSKap\n', 'Superhero Headquarters #ChatGPT #StableDiffusion #AIArt 2/3  https://t.co/QCS4waGXmA\n', 'Will ChatGPT mark the beginning of the end of many novel business ideas, including prompt marketplaces?   #ChatGPT  https://t.co/MeBQzZbUgp\n', '#chatGPT  https://t.co/Cq7a ...
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129401 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129327 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 27231 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 26800 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 32722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 33258 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 28982 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 35328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 35486 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 20966 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 29702 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129324 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129525 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128317 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129321 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 10024 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128247 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 129315 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128154 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:240: RuntimeWarning: Glyph 128640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129401 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129327 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 12398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 27231 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 26800 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 23398 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 32722 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 33258 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 28982 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 35486 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 20966 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 29702 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129309 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129324 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129525 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128317 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129321 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 10024 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128247 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 129315 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128154 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/matplotlib/backends/backend_agg.py:203: RuntimeWarning: Glyph 128640 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# <h2>Detemining optimal number of clusters using elbow method</h2>

# %%
# Determine the optimal number of clusters using the elbow method
last = Z[-10:, 2]
last_rev = last[::-1]
idx = np.arange(1, len(last) + 1)
plt.figure(figsize=(10, 5))
plt.plot(idx, last_rev)

# %%
# Calculate the second derivative of the distances
acceleration = np.diff(last, 2)

# Find the index of the elbow point, where the acceleration is highest
elbow_idx = np.argmax(acceleration) + 2

# Plot the elbow point
plt.axvline(x=elbow_idx, color='r', linestyle='--')
plt.title('Elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('Distance')
plt.show()

# Use the optimal number of clusters to perform clustering
n_clusters = elbow_idx
labels = fcluster(Z, n_clusters, criterion='maxclust')

# %%
n_clusters
# Out:
# 9

# %% [markdown]
# ignore the rest

# %%
model = AgglomerativeClustering(n_clusters=2, metric='euclidean', linkage='ward')
model.fit(Z)
labels = model.labels_

plt.scatter(Z[labels==0, 0], Z[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(Z[labels==1, 0], Z[labels==1, 1], s=50, marker='o', color='blue')

plt.show()

# %%
model = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
model.fit(Z)
labels = model.labels_

plt.scatter(Z[labels==0, 0], Z[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(Z[labels==1, 0], Z[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(Z[labels==2, 0], Z[labels==2, 1], s=50, marker='o', color='green')
plt.show()

# %%
model = AgglomerativeClustering(n_clusters=5, metric='euclidean', linkage='ward')
model.fit(Z)
labels = model.labels_

plt.scatter(Z[labels==0, 0], Z[labels==0, 1], s=50, marker='o', color='red')
plt.scatter(Z[labels==1, 0], Z[labels==1, 1], s=50, marker='o', color='blue')
plt.scatter(Z[labels==2, 0], Z[labels==2, 1], s=50, marker='o', color='green')
plt.scatter(Z[labels==3, 0], Z[labels==3, 1], s=50, marker='o', color='purple')
plt.scatter(Z[labels==4, 0], Z[labels==4, 1], s=50, marker='o', color='orange')
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import AgglomerativeClustering

# Load the text data
with open('dataframe_0_preprocessed.txt', 'r') as f:
    documents = f.readlines()

# Create a bag-of-words matrix
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(documents).toarray()

# Perform agglomerative clustering
agg_cluster = AgglomerativeClustering(n_clusters=3)
agg_cluster.fit(X)

# Get the cluster labels
labels = agg_cluster.labels_

# Print the results
df = pd.DataFrame({'document': documents, 'label': labels})
print(df)
# Out:
#                                              document  label
# 0   I want to increase my Twitter followers. At le...      1
# 1   Overall, using AI to create art can expand the...      0
# 2   This prompt was created with #ChatGPT the new ...      0
# 3   Just played around with OpenAI's new #ChatGPT ...      0
# 4   I asked #ChatGPT to write me a story about Sov...      1
# 5   OpenAI's new ChatGPT is very good at creative ...      1
# 6   This is a great improvement! Unlike text-davin...      1
# 7    #ChatGPT #OpenAI Wow!  https://t.co/aMUgPMtuoa\n      1
# 8   My mind is blown. I cannot believe how good Ch...      0
# 9   Absolutely insane. I asked #chatGPT to generat...      0
# 10  It is incredible how #chatgpt manages to propo...      0
# 11  #ChatGPT is pretty mind-blowing.  https://t.co...      1
# 12  OpenAIのChatGPT :)  https://t.co/oXakUrC9os @Op...      1
# 13  #ChatGPT from @OpenAI released today and is re...      1
# 14                   #ChatGPT from #OpenAI is here!\n      1
# 15  The new #chatGPT from @openAI (thanks to @GuyP...      0
# 16  Write a poem about a little child longing to b...      1
# 17  In the not too distant future, a helpful assis...      0
# 18  A cute little poem open about quarks from #Cha...      1
# 19  I used @OpenAI new AI system #ChatGPT which is...      0
# 20  woops, just gave the AI an existential crisis ...      1
# 21      Flipo with #ChatGPT https://t.co/Ii365D5Ehx\n      1
# 22  #ChatGPT far too deep for me 🤯  https://t.co/i...      1
# 23  @GuyP @OpenAI @readwise save thread @SaveToNot...      1
# 24  #ChatGPT may not like children very much, but ...      1
# 25  @marmite I've just found a new member for your...      1
# 26  Superhero Academies, Apartments, Research and ...      1
# 27  Superhero Headquarters #ChatGPT #StableDiffusi...      1
# 28  Will ChatGPT mark the beginning of the end of ...      1
# 29                #chatGPT  https://t.co/Cq7aWNCeSb\n      1
# 30  I asked #chatGPT to create me a modal upsell i...      0
# 31                #ChatGPT  https://t.co/u1dEcezQp6\n      1
# 32              🤬 #ChatGPT  https://t.co/mskOeAWLcp\n      1
# 33  #Chatgpt-3, quickly defeated by @ernestsdavis,...      1
# 34  Bouncing some ideas off my new AI friend here....      0
# 35  A fun part of @OpenAI's #ChatGPT: add "like I'...      1
# 36  The Twitter takeover as reenacted by Homer and...      1
# 37  New model in town: #ChatGPT. Will read on week...      0
# 38  AI can design games as well as game art now!! ...      0
# 39  #IA: mise en abyme OpenAI offers a #ChatGPT to...      0
# 40  My most recent column in @pulso_capital on #Ch...      1
# 41  Hey @taylorswift13 🤝 @OpenAI #WiFi #ChatGPT  h...      1
# 42  AI can help candidates learn how to answer beh...      0
# 43  #SoftwareEngineer #softwaredevelopment #Softwa...      1
# 44  @EcoOneE #ChatGPT a pre-trained obstetric conv...      1
# 45  AI is trained using up to 10 billion quadrilli...      2
# 46  Love you too @OpenAI @branchmetrics #chatGPT #...      1
# 47  Playing with #ChatGPT be like:  https://t.co/7...      1
# 48  Ok so now the poll has ended, the answer was 2...      0
# 49  Wow, I thought it was inaccessible to the outs...      1
# 50  Told #chatGPT to write a script of Future and ...      0
# 51  ChatGPT may not be a replacement for Google, b...      0
# 52  OK so @OpenAI's new #ChatGPT can basically jus...      0
# 53  use #ChatGPT to become the best version of you...      1
# 54  But, well! It turns out that #ChatGPT knows no...      0
# 55  #chatGPT Crypto FOMO Start #Crypto AI Projects...      1
# 56  ChatGPT couldn’t answer a simple probability q...      1
# 57       F**k Me  #ChatGPT  https://t.co/Le5SDIsCHz\n      1
# 58  Asked #ChatGPT to create a marketing email for...      1
# 59  I did a #ChatGPT thing based on a recommendati...      1
