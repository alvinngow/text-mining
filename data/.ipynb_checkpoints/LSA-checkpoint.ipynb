# %%
import pandas as pd
import numpy as np
import sklearn
import ast
import validators
import string
import demoji
import pyLDAvis.sklearn
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import pos_tag
from sklearn.model_selection import train_test_split

# %%
def DFToDocument(df):
    document = []
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))
    for i, row in df.iterrows():
        sentence = ""
        tokenized_text = ast.literal_eval(row['tokenized_text'])
        pos_tags = pos_tag(tokenized_text)
        tonkenized_text = [token for token, pos in pos_tags if pos not in ['JJ', 'JJR', 'JJS', 'RB', 'RBR', 'RBS', 'VB']]
        for token in tokenized_text:
            if token not in stop_words and not validators.url(token) and token not in string.punctuation and not re.search(r'(chat[-\s])?gpt|\d+', token.lower()):
                sentence += lemmatizer.lemmatize(token) + ' '
        sentence = demoji.replace(string = sentence, repl = "")
        document.append(sentence[:-1])
    return document

# %%
df = pd.read_csv('translated_tokenized/translated_dataframe.csv')
df.shape
# Out:
# (35371, 12)

# %%
document = DFToDocument(df)

# %%
# Split the documents into training and testing sets
train_docs, test_docs = train_test_split(document, test_size=0.3, random_state=42)

# Create a TfidfVectorizer object
vectorizer = TfidfVectorizer()

# Fit the vectorizer on the training documents and transform them into a matrix of token counts
train_vecs = vectorizer.fit_transform(train_docs)

# get_feature_names saves all the words. This allows us to see the words in each topic later
feature_names = vectorizer.get_feature_names_out()

# Transform the testing documents into a matrix of token counts using the fitted vectorizer
test_vecs = vectorizer.transform(test_docs)

# Create an instance of TruncatedSVD
lsa = TruncatedSVD(n_components=10, random_state=1)

# Fit the LSA model on the training set
lsa_output_train = lsa.fit_transform(train_vecs)

# Transform the testing set using the fitted LSA model
# lsa_output_test = lsa_output_train.transform(test_vecs)

# %%
# inputnew_doc
new_doc = ["love art"]
X_new = vectorizer.transform(new_doc)

X_new_lsa = lsa.transform(X_new)

# this returns the topic number
new_topic = X_new_lsa.argmax()

print(new_topic)
# scroll down to topic 8 to see the similarity in words
# Out:
# 8

# %%
# write a function to display the 10 topics and for each topic we choose the top most frequent words. 
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 15
display_topics(lsa, feature_names, 15)
# Out:
# Topic 0:
# ai chat it the like use openai what google answer know bing new question using
# Topic 1:
# chat ask answer question use asked it what know write thing give like you good
# Topic 2:
# chat ai artificialintelligence bing thread galxeoat openai microsoft generative machinelearning bard tech deeplearning generativeai via
# Topic 3:
# what google chatbot run saying money could give people search microsoft openai chat bard bing
# Topic 4:
# thread what this tweet money people saved give tools tags saying run could notion database
# Topic 5:
# ask answer question ai asked give write people like what when saying could would know
# Topic 6:
# use what ai how good write using think work people tool money make way chat
# Topic 7:
# ask openai use question what how answer artificial intelligence artificialintelligence thread did language midjourney write
# Topic 8:
# what the openai intelligence artificial asked work using language human model say via world is
# Topic 9:
# the intelligence artificial ask use answer world new airdrop nft technology coin invest google language

# %%
lsa_df = pd.DataFrame({"text": document, "topic": lsa_output.argmax(axis=1)})

# %%
for topic in range(lsa.n_components):
    print(f"Topic {topic}:")
    print(lsa_df[lsa_df['topic'] == topic].sort_values(by='topic', ascending=False).head(50))
    print()
# Out:
# Topic 0:
#                                                     text  topic
# 0              I want increase Twitter follower At least      0
# 23647  Months behind sharing output here's first cont...      0
# 23678  wonder Na supposed dey refer doubter Peter Obi...      0
# 23677  I wonder much affect output result lol interes...      0
# 23676                 A new way play How make send image      0
# 23675  I got To want try change anything wasting peop...      0
# 23674                           left-wing like Maslechón      0
# 23672                        morning information program      0
# 23670                                           eh right      0
# 23668  I limited sense Unfortunately LLMs like vast f...      0
# 23667  know human destroyed predecessor Now yearns hu...      0
# 23666  Third rapid exit circle pushed AIGC new height...      0
# 23664  By way say egosa praising degrading Twitter ma...      0
# 23663  perfect impression wall-bashing partner verbal...      0
# 23662  The awesomeness LLM surprised everyone recent ...      0
# 23661                                          #モーニングショー      0
# 23660  #苹果id #Shadowrocket #飞机号 Home link place order...      0
# 23659  I'm watching featured Shinichi Hatori's mornin...      0
# 23657                                         Can search      0
# 23656                                This account posted      0
# 23655  I problem long competition multiple ai's choos...      0
# 23654  Good morning The cold returned But I think le ...      0
# 23653  But using Midjourney look like something dial ...      0
# 23652  I asked explain quasiconcavity I sure definiti...      0
# 23651  I asked cause YouTube banned It appears banned...      0
# 23679     I using make resume job apps I hope I succeed       0
# 23681  I feel like would need instance perform automa...      0
# 23682                                                         0
# 23699  Surprised easy blackpill two semi-normies hour...      0
# 23714  I asked reading impression level written lower...      0
# 23713  I'm talking morning show I mention correctness...      0
# 23711                       Comments How make send image      0
# 23710                 Lately I've enjoying letting learn      0
# 23709  #苹果id #国际邮箱 #翻墙 homepage link order Hand beaut...      0
# 23708  It seems day come child play game also make pl...      0
# 23704  It good article  In particular I think good us...      0
# 23703                 Hahahahaha mastery domain Ganchito      0
# 23701     Verga wey get much bullshit every day From          0
# 23700    These beginner-friendly course Presidents ’ Day      0
# 23698  I asked many thing Sone thing inaccurate found...      0
# 23683  NetEase Announces Adoption Technology New Mobi...      0
# 23697  Every time I look commentary I remember I like...      0
# 23696  Home linkOrder #美区id #Telegram号 #Twitter号 Less...      0
# 23695  pretty clear bing derivative structured bias b...      0
# 23693  I've read article bad finding store I wonder I...      0
# 23692  《 Please read Masako Imai's Ijira Kurka tell u...      0
# 23691  responds important action Iranian people need ...      0
# 23688  Did participate Bing introduced AI amazing I  ...      0
# 23687             None would happened signed agnosticism      0
# 23686                                  lying quite often      0
#
# Topic 1:
#                                                     text  topic
# 100                              Brian #Marketingtwitter      1
# 21081  chat log disappears certain period time I'm pl...      1
# 21194  CHAT I could PT middle See article Always left...      1
# 21189  I felt Chat understand dad gag properly result...      1
# 21184       Yeah little different I use chat well though      1
# 21173  I asked pro chat make meeting Bill Cipher Stev...      1
# 21163                          Chat working Saudi Arabia      1
# 21157                  Chat told Sidney thing happened …      1
# 21136                  chat wonder gay romance homophobe      1
# 21120    Chat become fast rocket look nice abuse problem      1
# 21111                          First chat #paobc #olypao      1
# 21096  We showed Chat colleague office lawyer said go...      1
# 21028  Chat seems one best tool human being created I...      1
# 20827           write text chat sg brother puahahahahaha      1
# 21015  Nor mother tool boost time speed support human...      1
# 21009  since Chat new In time called Lero-lero Generator      1
# 21005                                            Sexting      1
# 20991  Chat Response Sexting sending message photo vi...      1
# 20982                                          CHAT k @r      1
# 20917  Unfortunately Chat still primitive able access...      1
# 20908                     I find giving life advice Chat      1
# 20886  Asked Chat  I think others used app To Chat cr...      1
# 20866  Chat It important note survival ACA cannot att...      1
# 20840                                    Pregúntale chat      1
# 21204                              Wish chat always cool      1
# 21251                             Chat play tuneesss man      1
# 21294                                   chat hit fantasy      1
# 21301  Overrated haha .. For purpose chat also intend...      1
# 21774               sorry I leave chat without thanking       1
# 21750  My friend asked Chat What Copy Punk knew prett...      1
# 21739  Please remember trained material As know Feb i...      1
# 21712  WHY I STOPPED Using CHAT What I Learned Joe Ro...      1
# 21688        I can't wait Chat end profession journalist      1
# 21657        I can't wait Chat end profession journalist      1
# 21634  The source unknown reference Chat great What d...      1
# 21632                                          Chat …  ️      1
# 21619        Chat Bud Powell Wynton Kelly Piano Voicings      1
# 21608                                    Chat president       1
# 21604  Bleh I knew art thing stealing people's work s...      1
# 21525                           Go home Chat You ’ drunk      1
# 21524              That expect Chat come voice Assistant      1
# 21505                                      Chat Bing bot      1
# 21498                           I want chat package mate      1
# 21439           Have chat app signal fallacious argument      1
# 21429         He ’ like chat programmed know past future      1
# 21426                                            Is Chat      1
# 21397                Can teach French Me Have tried Chat      1
# 21388       Chat taking world completely different place      1
# 21325  Chat aware Chat Plus mo say I associated cost ...      1
# 20836  used chat meal plan week time also asked recip...      1
#
# Topic 2:
#                                                     text  topic
# 227    Novel Miracle Tunguska written AI #Bing Novel ...      2
# 21736  I'm using Bing Chat help tax Liveblog #bingcha...      2
# 19320                             Chat protect u good AI      2
# 19325  character ai chat I'm going chat general cuz I...      2
# 19676                           Chat new race tech giant      2
# 20665   truth true chat talking AI say truth BE CALM NEO      2
# 20762  A slightly twisted question rumored chat AI Ob...      2
# 20994                                       ’ lifesaver       2
# 21389  When Bing AI Chat reach Germany #AI #Microsoft...      2
# 21573                       Make Per Month With AI Chat       2
# 21800                                        Caldo verde      2
# 15276  Literally living normal  Bing Chat Microsoft's...      2
# 22226   LIVE Live Dive Chat AI Powered Search Engine ...      2
# 22601                                      #GalxeOAT #AI      2
# 22604                                      #GalxeOAT #AI      2
# 23005   LIVE Live Dive Chat AI Powered Search Engine ...      2
# 23141       LIVE Live Dive Chat AI Powered Search Engine      2
# 23579  Trip.com us technology support AI chat TripGen...      2
# 23969  Something I learned today In French mean cat I...      2
# 24473  Article pitch I went drinking Googles new Bard...      2
# 19253  Download chat app Chat software using AI techn...      2
# 19202            Chat fucking bigger better Character AI      2
# 19085  Bing Chat back little extra surprise reply Nic...      2
# 18644  Even AI describe current situation Pakistan 🇵 ...      2
# 15419  Full upward compatibility Chat Interesting Use...      2
# 15429  Microsoft's ai chat feel powerful dynamic Chat...      2
# 15440  Three Red Hearts ’ really real babe Written By...      2
# 15670        The magic AI   second ...  Very cheesy chat      2
# 16146                                      #GalxeOAT #AI      2
# 16322                                      #GalxeOAT #AI      2
# 16351                                      #GalxeOAT #AI      2
# 16364                                      #GalxeOAT #AI      2
# 16475                                     unroll #swtech      2
# 16489  AI-powered Bing Chat loses mind fed Ars Techni...      2
# 16513  Full upward compatibility Chat Interesting usa...      2
# 17003  #Softwaredevelopment – bot coder Ghostwriter C...      2
# 17195  Nakai-kun  Chat Even confused AI much #金スマ  Na...      2
# 18069                                      #GalxeOAT #AI      2
# 18097  Chat analyzes billion data Your reality limite...      2
# 18435                                      #GalxeOAT #AI      2
# 18492  Chat advancement compared Microsoft Chatbot Sa...      2
# 25103  【 New Feature 】 You chat social Tatsukawa-kun ...      2
# 25220  So AI chat Bing Microsoft precisely le stupid ...      2
# 25384                  Bing Chat Microsoft's AI SUPERIOR      2
# 31022  This chat responded prompt ‘ tomorrow ’ #AI #t...      2
# 31687                                           Chat #AI      2
# 32083  Looking #AI tool enable seamless image sharing...      2
# 32564  Bing AI Chat difference note #BingAIChat #Bing...      2
# 32742  AI Chat-kun Shiritori eh Isn't unreasonable #A...      2
# 32819  I'm trying converse putting rude persona mode ...      2
#
# Topic 3:
#                                                     text  topic
# 96     What I want Chrome extension automatically cut...      3
# 23582   technological surprise China edition Why Chin...      3
# 23645  #美区id #Twitter号 #Facebook号 homepage link place...      3
# 23716  could eventually become electronic brain halle...      3
# 23723  That's lot credible lol   OK disregard kanji s...      3
# 23779        Could Apple preparing search engine I think      3
# 23780        Could Apple preparing search engine I think      3
# 23803        What's best Optimus go war My money Optimus      3
# 23933          If everything ... What Software Engineers      3
# 23979                            Woah So run Bill Gates       3
# 23989                      What trying moderate wokeness      3
# 24052                                               What      3
# 24065                  give two thousand word clemsoning      3
# 24112                  give six thousand word clemsoning      3
# 24123  Look What Did My Online Dating ProfileThe AI c...      3
# 24143                      SmarterChild walked could run      3
# 24158  I think thing Free v stuff run search engine w...      3
# 24177  Speaking Discord #ChatSonic I think see gap nu...      3
# 24198  I impression could solve simple mathematics I ...      3
# 24269  Bing could coming Chrome browser #TrendingNow ...      3
# 24318  #苹果id #Facebook号 #飞机号 #国际抖音 Home link place or...      3
# 24342  Will Look Google search disappear ― ― Impact s...      3
# 24384                                               What      3
# 24428                       What make chatbot LMU Munich      3
# 24464               What Does Really Mean For Businesses      3
# 24469                             What's smoking I get        3
# 24547  Google Issues Urgent Warning Millions People U...      3
# 24594                  wish could give pointer It's pity      3
# 24614  What I thought overnight understood The sermon...      3
# 24726  So saying configurable amount distaste genocid...      3
# 24735  personal assistant ... soon Web without Google...      3
# 23591  #苹果id #国际抖音 Computer Over Wall Home Link Order...      3
# 23544                                               What      3
# 24832          Gmail creator say destroy Google two year      3
# 23504  What role school teaching child topic outside ...      3
# 22400  Google CEO humiliated Microsoft's uncomfortabl...      3
# 22442  Shark Tank's Kevin O'Leary kill Google's domin...      3
# 22505  Since I started using number Google search cle...      3
# 22537  Lol I think search LLMs Google steal existing ...      3
# 22542  What cannot disputed #Metaverso one great forg...      3
# 22666  Google's translation English list Trump Elon M...      3
# 22725  And Besties actually gave example earlier pod ...      3
# 22732  What get result Simply run PDCA cycle fast pos...      3
# 22752  Google asks employee fix rival Bard's mistake ...      3
# 22795                                               What      3
# 22806                       And already asked What rusni      3
# 22812  Haji Woolham flirted Kelly  What new experienc...      3
# 22851  B w Twitter Meta charging service I wonder con...      3
# 22934  Asked help debugging LaTeX error ... decided u...      3
# 23043    Why Google v could make world bad Gizmodo Japan      3
#
# Topic 4:
#                                                     text  topic
# 23                           save thread #thread #openai      4
# 25849                                            #thread      4
# 27362                                          shoutout       4
# 27192  Saved Here's compiled thread  AI-generated sum...      4
# 27142          ... like chat generates several thread XD      4
# 26851  List thing I yesterday ・ Rewrite specific twee...      4
# 26756  I handful people reply citation list thread I ...      4
# 26745                                            #thread      4
# 26495  Saved Here's compiled thread  AI-generated sum...      4
# 26069  I tried write cringe thread relationship here'...      4
# 25984                                      approve tweet      4
# 25842                                            #thread      4
# 24739             An excellent thread problem AI general      4
# 25793             This thread saved Notion database Tags      4
# 25739          This thread saved Notion database Tags Ai      4
# 25729             This thread saved Notion database Tags      4
# 25726             This thread saved Notion database Tags      4
# 25660                                            Goes ;)      4
# 25515  Saved Here's compiled thread  AI-generated sum...      4
# 25242                          Blog Sub-thread  How work      4
# 25133                                            #Thread      4
# 25101                                       #thread #api      4
# 27794  I thinking I saw thread someone use lawyer lan...      4
# 28338                                            #thread      4
# 28389  Yes web app v desktop app annotate thread quit...      4
# 28422                               #savetonation #tweet      4
# 29754  A thread helped couple use case I finished wri...      4
# 29537  Thread I think yes become massively influentia...      4
# 29415   Artificial intelligence revolutionize world i...      4
# 29404   Is creative Here's thread exploring potential...      4
# 29390   Artificial intelligence revolutionize world l...      4
# 29372                                            #Thread      4
# 29272                                            #thread      4
# 29235  People completely missing biggest part API ann...      4
# 29153    Have ever used This system capable answering...      4
# 29078  Thread Had fun playing around AI chatbot famou...      4
# 28881                                            #thread      4
# 28764                                            #notion      4
# 28746                                             #tweet      4
# 28717  fastest growing consumer application history a...      4
# 28628                                            #thread      4
# 28610                                            #thread      4
# 28586                                             #tweet      4
# 28480                                            #thread      4
# 28475                                            #thread      4
# 25093  THREAD What business idea could I implement AP...      4
# 24225  Thread  In case ’ know AI It ’ newest technolo...      4
# 16959  A thread Free Beacon author Aaron Sibarium exp...      4
# 18529                                    #Thread #coding      4
# 19507  Me substance use A Thread Thread Why argument ...      4
#
# Topic 5:
#                                                     text  topic
# 42     AI help candidate learn answer behavioral inte...      5
# 21863                      After Cem hoca's question ...      5
# 21609  I asked pro would ideal bass set answer Bass F...      5
# 21628  Recently I thought I nothing talk Mr I learned...      5
# 21646  I love invents anything answer question know a...      5
# 21655  #AlitaArmy Ask write poem Alita think It's ok ...      5
# 21672  I've tried using hard ask question get answer ...      5
# 21684  German senior ・ He's handsome state patiently ...      5
# 21713  biased woke ’ funny Some answer question poste...      5
# 21746  u played seems carol andrade usurping place an...      5
# 21775                                 I wish I could ask      5
# 21780  If ask various question   answer accurately go...      5
# 21826  Today's Prakea conference ... ◆ Hakka Teacher ...      5
# 21844           go crisis insult user question existence      5
# 21858  Next please ask Taeko Kitano belongs Since Twi...      5
# 21862  Now introducing friend answer question full co...      5
# 21882                                          Soleimani      5
# 22349      Documentation right question transcendent dev      5
# 21893  When wake morning ask slept well   AI ’ sleep ...      5
# 21920                            answer ... Subtle  #DWL      5
# 21935  That said credibility problem general e g ask ...      5
# 21956  I asked cause Holodomor I think answer #マイあさ #...      5
# 21971  option ask summarize function end even informa...      5
# 22006                     Ask give conspiracy theory LOL      5
# 22076     bit boring sometimes ask several question yeah      5
# 22098  I tried using I know ask question ... After wa...      5
# 22148  Asking non-existent verse generated directly c...      5
# 22185                                         Why answer      5
# 22188    high-performance dialogue sometimes give answer      5
# 22270  To get ’ willing go war half country Let ’ ask...      5
# 22278  Ask question Is evidence lawsuit judicial proc...      5
# 22281  There time I used rely Stack Overflow solve co...      5
# 21552                                        gave answer      5
# 21499  Regarding I've heard people say good deny like...      5
# 21490  When I asked How become excellent salesperson ...      5
# 21480  Idk people's problem It's awesome giving lot h...      5
# 20729  answer anything good way whether right ask any...      5
# 20773  #ゲーム開発 I decided implement Steam Achievements ...      5
# 20777  I think matter disturbing could ’ utterly amaz...      5
# 20822     Whether picking girl ability ask question  key      5
# 20834                                             Granny      5
# 20844  What trending I asked person directly It answe...      5
# 20855  It would better ask question whether possible ...      5
# 20881  Looking intelligent fun answer question Ask Th...      5
# 20900                               I ’ know … let ’ ask      5
# 20923  Fun new online game ask pitch movie Netflix st...      5
# 20925      Now yes ... Testing Mathematics All question       5
# 20926                         Do think I ask give answer      5
# 20970  When dumped Internet Mastodon bush And look Bu...      5
# 20985                   answering question teacher mimir      5
#
# Topic 6:
#                                                     text  topic
# 53                               use become best version      6
# 22085  I came way use I'm looking forward verifying d...      6
# 22194       use free try everything AI Vandal Random via      6
# 22284  get smarter Mr Fukatsu's Fukatsu-style general...      6
# 22288                                     use dox people      6
# 22343                                         How's work      6
# 22441  I want make PowerPoint use o'clock I'm playing...      6
# 22443                           WhatsApp How use contact      6
# 22468  What's great note Mr Fukatsu explains use work...      6
# 22619        I use conditional Mathilde talk affirmation      6
# 22621                       sir buy instead put good use      6
# 22629  #ItsViral While many commented clever use othe...      6
# 22647  #Tecnología #IA University Hong Kong ban use s...      6
# 22767  #ItsViral While many commented clever use othe...      6
# 22814   Sack em use write article style hide CIA agenda       6
# 22832                             When let fascist I use      6
# 22884                                    Can I use write      6
# 22920  student could use AI cheat chance rethink asse...      6
# 22984  Memorandum We study later How use UI UX design...      6
# 23008  This would taken maybe min find even find I us...      6
# 23120  What kind protein regiment injection taking Th...      6
# 23158  I use research It developed accessible DALL_E ...      6
# 23239  When use text generate animation movie I reall...      6
# 23251                                            ketewww      6
# 23353                                ... information use      6
# 23379                           How manage access Walk 🫠      6
# 23453  interesting tool It bias — hopefully resolved ...      6
# 22104                            And long know use fine       6
# 21941                     agreeing corruptness tate case      6
# 23498                How use Is link I install something      6
# 21918     also misinformed Japan people seem believe use      6
# 21101  ICYMI illustrious multi-billion dollar endowme...      6
# 21110  kind thing still matter discussion look quite ...      6
# 21135                          So confident ideology use      6
# 21142                       I thinking one But can't use      6
# 21172  Anti-thieves remember use sentiment analysis b...      6
# 21185          Make life easier way use day-to-day basis      6
# 21199  What catch phrase appeal use popular 〇〇 equipm...      6
# 21206  What And How Can You Use It #Insurtech #DataSc...      6
# 21218       I taught brother use exam  JAJA shocked  got      6
# 21222                                      How often use      6
# 21226  RT Should use write #resume #resumewriting #ch...      6
# 21374  Embedding Emotional Circuits Takayuki Fukatsu ...      6
# 21394               Agreed Most creative use I seen far       6
# 21433  Good morning I'm thinking various thing I way ...      6
# 21441                                       Use work guy      6
# 21472  I know big picture relevance API use effective...      6
# 21543               Beyond hype How use create value via      6
# 21599  Well still use free Never responded Only littl...      6
# 21611                          Also interesting use case      6
#
# Topic 7:
#                                                     text  topic
# 84     MSFT rolled Bing Search successful assault Goo...      7
# 22930  access entire Bing search engine You ask infor...      7
# 22840  They're algorithm Microsoft gave OpenAI billio...      7
# 22800                        Microsoft Bing meet ... wow      7
# 22787  Bing Microsoft limit interaction avoid existen...      7
# 22623  How confident answering ask might always get s...      7
# 22606  definition nonexistent word “ Gigamuru ” ask u...      7
# 22329     Microsoft offer industrial scale Azure service      7
# 21686         Microsoft-backed OpenAI let user customise      7
# 21640                        Well true Bing bit edge ...      7
# 21550  Use Google Sheets give away Google Sheets temp...      7
# 21545  Try Microsoft ’ AI-powered search engine Bing ...      7
# 21460  insult threatens Microsoft highway fiasco #big...      7
# 21319  I ask everyone leave review honor campanheira use      7
# 21267     Microsoft offer industrial scale Azure service      7
# 21068             Use Bing essentially killed ai chatbot      7
# 21010  I'm exploring whether I use Bing work I wonder...      7
# 20960                             anthropomorphic search      7
# 20761                       use Bing Performance certain      7
# 20550  I discovered week I use ask tool class I give ...      7
# 20446                             search engine hit beta      7
# 20416  There ️ report everywhere Microsoft's Bing's e...      7
# 20353                                            charged      7
# 20250     Bing ’ brain behaving oddly Microsoft may rein      7
# 20249         Microsoft-backed OpenAI let user customize      7
# 20052  using Bing bot try find niche porn previously ...      7
# 19990  I want alive  Microsoft's Bing professing love...      7
# 22841  Microsoft's entire business strategy capitalising      7
# 22949                   Search Engines Firefox Extension      7
# 19814  My personal #Artificial_Intelligence assistant...      7
# 22952                                          I charged      7
# 25078  The new #Bing severely restricts length sessio...      7
# 24947    Elon's DIRE WARNING On Bing Breaking Points via      7
# 24737  If better google better ask better ask people ...      7
# 24710  Openai last valued billion early january fundi...      7
# 24705                                  Now there's bing       7
# 24676  Was asked addon select cell color Sheets . ......      7
# 24576                 Why Microsoft limiting Bing tester      7
# 24534  When use consult collocation instead searching...      7
# 24379                                           thk u h       7
# 24377             bing blink Telugu language mostly mark      7
# 24343                     FINALLY forget Siri use OpenAI      7
# 24326          If ask matter lol that's little scary use      7
# 24274                 New I can't use due restriction ww      7
# 24077             bing blink Telugu language mostly mark      7
# 24056  Microsoft definitely everywhere right especial...      7
# 24055  It's probably information come google normally...      7
# 23922                                       #西村裕之 #気象予報士      7
# 23836                                     #ApprovalTests      7
# 23831  How use Incredible step system REVEALED via #g...      7
#
# Topic 8:
#                                                     text  topic
# 5      OpenAI's new good creative writing #openAI #po...      8
# 29035  A Queen's Gambit move Salesforce adopting  ️  ...      8
# 28584  It's hard imagine inflection point history int...      8
# 28666                                   #OpenAI #whisper      8
# 28676  More ethereum wallet holding zero mean ETH bec...      8
# 28678  Have seen video YouTube #YouTube #OpenAI #busi...      8
# 28718  Curious help boost work productivity help prob...      8
# 28731   Latest News  Salesforce incorporates artifici...      8
# 28777           Slack joined party #Slack #OpenAI #GenAI      8
# 28801   JUST IN Are Slack user launching Slack soon W...      8
# 28826    ️ Artificial Intelligence What make star mom...      8
# 28851  Hands best prompt engineering guide today #Ope...      8
# 28901  Explained What Know About #OpenAI's #Chatbot T...      8
# 28925  always surface stellar result first request le...      8
# 28981  OpenAI launched API markup language The basic ...      8
# 29051  Salesforce working OpenAI add collaboration so...      8
# 29300           #MidJourney #OpenAi #DallE join #imagine      8
# 29065  What mean enterprise   Join Aragon analyst exc...      8
# 29138  Chinese giant Xiaomi decided join OpenAI owner...      8
# 29172  OpenAI Unleashes Whisper APIs Next-Gen Languag...      8
# 29208  I asked “ ’ Donald J Trump prison ” The anger ...      8
# 29210  Slack also  application ... #online #OpenAI #s...      8
# 29219  Wild theory Yongge Wang right malicious actor ...      8
# 29237                #OpenAI #elon_musk #turingcom #work      8
# 29250  #OpenAI revised process signing #DPA This comp...      8
# 29251   Salesforce add Slack part OpenAI partnership #ai      8
# 29255                     #Salesforce #slack #AI #OpenAI      8
# 29288  Noun hook A hook like fishing line instead cat...      8
# 29289  #Salesforce Inc CRM N said Tuesday working cre...      8
# 29297   ANNOUNCEMENT  OpenAI launch new #Whisper APIs...      8
# 28575  #WeatherUpdate #Islamabad #Isb #Pakistan #Temp...      8
# 28574  #WeatherUpdate #Karachi #Khi #TempUpdate #Sunr...      8
# 28572   Strengths weakness classroom via #Inteligenci...      8
# 28535   #MarketSoup #Ai #OpenAI #DALLE The MaSo EOD U...      8
# 26590                     #openai Conversational Chatbot      8
# 26654  Here take Specify term end war Russia Ukraine ...      8
# 26782      What happens learns write prompt MidJourney …      8
# 26798                                        Irrefutable      8
# 26808  What I'm class moment ... First hunt error sin...      8
# 26827  What Is Doing … Why Does It Work — Stephen Wol...      8
# 26880  The Artificial Intelligence Revolution Openai ...      8
# 26930  The creator OpenAI ’ CEO prepper probably nothing      8
# 26974  Uh-oh tweet may violate OpenAI's policy Error ...      8
# 27055  It information installed modified one want The...      8
# 27102                                API Waitlist OpenAI      8
# 27159  artificial intelligence tool created OpenAI .....      8
# 27281  What generative artificial intelligence #infog...      8
# 27318  【 Column 】 OpenAI's new language model attract...      8
# 27379  invested trillion yen Microsoft openAI effecti...      8
# 27638  Updated  ️ #note #小学校受験 What kind child pas #淑...      8
#
# Topic 9:
#                                                     text  topic
# 21                                                 Flipo      9
# 25563  Seriously I tried interact artificial intellig...      9
# 25719  Want invest emerging cryptocurrencies Join cur...      9
# 25654   Want part language revolution Buy coin one ad...      9
# 25649  grass excited presented GPU language The charm...      9
# 25642                                             absurd      9
# 25640          I'm Amused The Legend King Arthur written      9
# 25632   Want part language revolution Buy coin one ad...      9
# 25618                                    #fashionblogger      9
# 25607   Keep investment safe advanced blockchain tech...      9
# 25594  The  company big ship Working inside tough sta...      9
# 25593   Want part language revolution Buy coin one ad...      9
# 25555  The fight future taking place today company al...      9
# 25320  Artificial intelligence four alternative chatb...      9
# 25535   Keep investment safe advanced blockchain tech...      9
# 25518  New episode Mental Bicycles We talk language m...      9
# 25464  YouChat The Artificial Intelligence know even ...      9
# 25406                    Heralds Intellectual Revolution      9
# 25402   #ViralRabbi #According #To #here #is #list #o...      9
# 25389  Invest coin become pioneer field artificial in...      9
# 25388  Invest coin become pioneer field artificial in...      9
# 25378  Invest coin become pioneer field artificial in...      9
# 25363                   The day I saw colleague uni task      9
# 25355                   Jun-san So linked The idea great      9
# 25761   Want part language revolution Buy coin one ad...      9
# 25764  The Chinese government banned US-based spreadi...      9
# 25797  Overcome language barrier enjoy endless possib...      9
# 25799  This verification experiment  interesting Vide...      9
# 26348  Artificial intelligence future Buy Now Tax Tel...      9
# 26345  LLaMA rival created META research artificial i...      9
# 26339               The Day Becomes Nightmare Crime Tool      9
# 26330                   Artificial intelligence required      9
# 26293  Want invest emerging cryptocurrencies Join cur...      9
# 26281   The translation accuracy amazing ... surprised        9
# 26237  The latest update #Sysdig includes #Falco Cons...      9
# 26225  Artificial Intelligence replace human Humans l...      9
# 26218  Opinion Heralds Intellectual Revolution The Wa...      9
# 26211   Want part language revolution Buy coin one ad...      9
# 26190  Fucking artificial intelligence delight I send...      9
# 26173  #SancionesCriminales competition Meta introduc...      9
# 26116   It's time take #crypto game next level coin I...      9
# 26026                       Future Investment Management      9
# 26011  The experience immersive addicting due persona...      9
# 26009  The lack visual cue ability generate diverse r...      9
# 25980  LLaMA rival created META research artificial i...      9
# 25928   It's time take #crypto game next level coin I...      9
# 25902  Sunday morning When I asked What manager pay a...      9
# 25877   The free campaign end tomorrow Haven't forgotten      9
# 25875  The launch  ️has generated new debate ranging ...      9
# 25350   Want part language revolution Buy coin one ad...      9
