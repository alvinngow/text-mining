# %%
import pandas as pd
import numpy as np
import sklearn
import ast
import validators
import string
import demoji
import pyLDAvis.sklearn
import re

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import make_pipeline
import pandas as pd
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk import pos_tag
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV

# %%
def DFToDocument(df):
    document = []
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))
    for i, row in df.iterrows():
        sentence = ""
        tokenized_text = ast.literal_eval(row['tokenized_text'])
        pos_tags = pos_tag(tokenized_text)
        tonkenized_text = [token for token, pos in pos_tags if pos not in ['JJ', 'JJR', 'JJS', 'RB', 'RBR', 'RBS', 'VB']]
        for token in tokenized_text:
            if token not in stop_words and not validators.url(token) and token not in string.punctuation and not re.search(r'(chat[-\s])?gpt|\d+', token.lower()):
                sentence += lemmatizer.lemmatize(token) + ' '
        sentence = demoji.replace(string = sentence, repl = "")
        document.append(sentence[:-1])
    return document

# %%
df = pd.read_csv('translated_tokenized/translated_dataframe.csv')
df.shape
# Out:
# (35371, 12)

# %%
document = DFToDocument(df)

# %%
# Split the documents into training and testing sets
train_docs, test_docs = train_test_split(document, test_size=0.3, random_state=42)

# Create a TfidfVectorizer object
vectorizer = TfidfVectorizer()

# Fit the vectorizer on the training documents and transform them into a matrix of token counts
train_vecs = vectorizer.fit_transform(train_docs)

# get_feature_names saves all the words. This allows us to see the words in each topic later
feature_names = vectorizer.get_feature_names_out()

# Transform the testing documents into a matrix of token counts using the fitted vectorizer
test_vecs = vectorizer.transform(test_docs)

# Create an instance of TruncatedSVD
lsa = TruncatedSVD(n_components=10, random_state=1)

# Fit the LSA model on the training set
lsa_output_train = lsa.fit_transform(train_vecs)

# Transform the testing set using the fitted LSA model
# lsa_output_test = lsa_output_train.transform(test_vecs)

# %%
# inputnew_doc
new_doc = ["love art"]
X_new = vectorizer.transform(new_doc)

X_new_lsa = lsa.transform(X_new)

# this returns the topic number
new_topic = X_new_lsa.argmax()

print(new_topic)
# scroll down to topic 8 to see the similarity in words
# Out:
# 8

# %%
# write a function to display the 10 topics and for each topic we choose the top most frequent words. 
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic %d:" % (topic_idx))
        print(" ".join([feature_names[i] for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 15
display_topics(lsa, feature_names, 15)
# Out:
# Topic 0:
# ai chat it the like use openai what google answer know bing new question using
# Topic 1:
# chat ask answer question use asked it what know write thing give like you good
# Topic 2:
# chat ai artificialintelligence bing thread galxeoat openai microsoft generative machinelearning bard tech deeplearning generativeai via
# Topic 3:
# what google chatbot run saying money could give people search microsoft openai chat bard bing
# Topic 4:
# thread what this tweet money people saved give tools tags saying run could notion database
# Topic 5:
# ask answer question ai asked give write people like what when saying could would know
# Topic 6:
# use what ai how good write using think work people tool money make way chat
# Topic 7:
# ask openai use question what how answer artificial intelligence artificialintelligence thread did language midjourney write
# Topic 8:
# what the openai intelligence artificial asked work using language human model say via world is
# Topic 9:
# the intelligence artificial ask use answer world new airdrop nft technology coin invest google language

# %%
for topic in range(lsa.n_components):
    print(f"Topic {topic}:")
    print(lsa_df[lsa_df['topic'] == topic].sort_values(by='topic', ascending=False).head(50))
    print()

# %%
search_params = {'n_components':[5,10,1],'algorithm': ['arpack', 'randomized'],
              'n_iter': [5, 10, 15],
              'random_state': [42],
              'tol': [0.001, 0.0001]}
docs_lsa = TruncatedSVD()
                        
model = GridSearchCV(docs_lsa, param_grid=search_params, scoring='accuracy', n_jobs=8, verbose=3)

model.fit(train_vecs)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# [CV 4/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 4/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 5/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 5/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 1/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 3/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 2/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 3/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 2/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 3/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 1/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.5s
# [CV 5/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 2/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 5/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 2/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.4s
# [CV 1/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 2/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 2/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 3/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 1/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.5s
# [CV 2/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 5/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 1/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 1/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 4/5] END algorithm=arpack, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=arpack, n_components=5, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=arpack, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=arpack, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=arpack, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=arpack, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 2/5] END algorithm=arpack, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=arpack, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=randomized, n_components=5, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=randomized, n_components=5, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 3/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 4/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 4/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 5/5] END algorithm=randomized, n_components=5, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py:778: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_validation.py", line 765, in _score
#     scores = scorer(estimator, X_test)
# TypeError: __call__() missing 1 required positional argument: 'y_true'
#
#   warnings.warn(
# /Users/eileengoh/opt/anaconda3/lib/python3.9/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# GridSearchCV(estimator=TruncatedSVD(), n_jobs=8,
#              param_grid={'algorithm': ['arpack', 'randomized'],
#                          'n_components': [5, 10, 1], 'n_iter': [5, 10, 15],
#                          'random_state': [42], 'tol': [0.001, 0.0001]},
#              scoring='accuracy', verbose=3)
# [CV 3/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 4/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 5/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.4s
# [CV 2/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.6s
# [CV 3/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.6s
# [CV 4/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 2/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.4s
# [CV 3/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 4/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.7s
# [CV 3/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 3/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.8s
# [CV 4/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.5s
# [CV 2/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.6s
# [CV 2/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 4/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.7s
# [CV 5/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.5s
# [CV 1/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.8s
# [CV 1/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.4s
# [CV 2/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 3/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 4/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.5s
# [CV 5/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.5s
# [CV 1/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.6s
# [CV 4/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 5/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.3s
# [CV 3/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 1/5] END algorithm=randomized, n_components=10, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 1/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.4s
# [CV 2/5] END algorithm=randomized, n_components=10, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.5s
# [CV 1/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.2s
# [CV 5/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=randomized, n_components=1, n_iter=5, random_state=42, tol=0.0001;, score=nan total time=   0.1s
# [CV 3/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 4/5] END algorithm=randomized, n_components=1, n_iter=10, random_state=42, tol=0.001;, score=nan total time=   0.1s
# [CV 1/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 4/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
# [CV 2/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.9s
# [CV 3/5] END algorithm=randomized, n_components=10, n_iter=10, random_state=42, tol=0.0001;, score=nan total time=   0.4s
# [CV 2/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.001;, score=nan total time=   0.3s
# [CV 5/5] END algorithm=randomized, n_components=1, n_iter=15, random_state=42, tol=0.0001;, score=nan total time=   0.2s
